# %%
import matplotlib.pyplot as plt

# %%
y=[7.88e-05,0.0058644,0.0236306,0.0548962,0.100221,0.156389,0.230349,0.318302,
   0.41482,0.531336,0.648702,2.67938,5.77435,10.274,16.98]
x=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
plt.plot(x,y,marker='o', linestyle='-', color = 'g',label='C++')
plt.legend()
plt.ylabel("Tiempo Promedio despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Tiempo Promedio c++")
plt.show()

# %%
y1=[3.27109e-06,0.000591476,0.000701587,0.000571098,0.00308646,0.00264777,0.00120131,0.00360121
,0.0010455,0.00319043,0.00503832,0.00776078,0.0181752,0.0217991,0.760432]

x1=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
plt.plot(x1,y1,marker='o', linestyle='-', color = 'g',label='C++')
plt.legend()
plt.ylabel("Desviacion Estandar")
plt.xlabel("Tamaño del array")
plt.title("Desvaicion Estandar C++")
plt.show()

# %%
x2=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
y2=[1.6371799999999998e-05,0.0011586674,0.0043495776,0.0101658006,0.019649689999999997,0.0345393576
,0.053155134199999995,0.0753763882,0.10246243800000002,0.136604837,0.18642754639999998,0.834085402
,1.9403158206,3.4065936598,5.6428803774]

plt.plot(x2,y2,marker='o', linestyle='-', color = 'b',label='Golang')
plt.legend()
plt.ylabel("Tiempo Promedio despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Tiempo Promedio Golang")
plt.show()

# %%
y3=[3.5901865132608362e-06
,0.00010834691562199634
,0.00028326397499558607
,0.0006650374316880971
,0.0006835161230241757
,0.0006769187845815039
,0.002082404032845498
,0.0013284295402010238
,0.0014969161395061493
,0.004381727337958175
,0.007785867474113259
,0.034356008859571054
,0.06551811627539031
,0.03612058097648337
,0.2235309878575576]

x3=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
plt.plot(x3,y3,marker='o', linestyle='-', color = 'b',label='Golang')
plt.legend()
plt.ylabel("Desviacion Estandar")
plt.xlabel("Tamaño del array")
plt.title("Desvaicion Estandar Golang")
plt.show()

# %%
x4=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000]

y4=[0.003043504001107067,0.2648732775938697,0.9997328679892235,2.2389981967862695,4.021273508376908
,6.272534796991385,8.86980914939195,12.156254998408258,15.903120075794869,20.163169759989252,24.95190793441143
,99.95106344461674,227.3]

plt.plot(x4, y4, marker='o', linestyle='-', color = 'y',label='Python')

plt.legend()
plt.ylabel("Tiempo Promedio despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Tiempo Promedio Python")
plt.show()

# %%
x5=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000]
y5 =[0.0004316591302297522
,0.014938947388038937
,0.006061772502042151
,0.01181403629063627
,0.013610673042576037
,0.023043088343481833
,0.24114016688269832
,0.24015278795378037
,0.31599742607279635
,0.2669615834967026
,0.30315922981319104
,1.4746620087255835
,2.956607642591096]

plt.plot(x5, y5, marker='o', linestyle='-', color = 'y',label='Python')

plt.legend()
plt.ylabel("Desviacion Estandar")
plt.xlabel("Tamaño del array")
plt.title("Desviacion Estandar Python")
plt.show()

# %%
plt.plot(x,y,marker='o', linestyle='-', color = 'g',label='C++')
plt.plot(x2,y2,marker='o', linestyle='-', color = 'b',label='Golang')
plt.plot(x4, y4, marker='o', linestyle='-', color = 'y',label='Python')
plt.legend()
plt.ylabel("Tiempo Promedio despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Comparacion entre tiempos promedios de C++,Golang y python")
plt.show()
